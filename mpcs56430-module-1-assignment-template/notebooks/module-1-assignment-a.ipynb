# %% [markdown]
# # 1. Join our Slack workspace
# ---
# * **Workspace invitation:** [Click here](https://join.slack.com/t/mpcs56430-2026-spring/shared_invite/zt-3tcmzjy4m-F8_9K_a_6RGbjTvzYSzIYg)
# * Choose a **"visible name"** in Slack that you would like to be called. You can edit this in your profile.
# * Set your profile image to a picture of yourself. Use a *headshot* so we can see you. This makes it easier for the instructors and your classmates to identify you.
# * Consult any resources for getting started in Slack (as needed):
#     * [Slack 101](https://slack.com/resources/slack-101)
#     * [Top 5 tips for getting started in Slack](https://slack.com/resources/using-slack/slack-tutorials)
#
# # 2. Post Your First Message in Slack
# ---
# * Create a post in the `#social` channel to introduce yourself to the class.
# * Include information about your background and anything else that may be interesting to your classmates. *For example, where did you go for undergrad, are you a full or part-time student, what specialization are you in, where are you living now, where do you work, etc.*
#
# # 3. Add Your Name to NameCoach
# ---
# Please record your name using the **NameCoach** tool in Canvas. You can find it on the sidebar. Please record the name you would like to be called by instructors and students.
#
# # 4. Setup Your Development Environment
# ---
# * Sign-up for a [GitHub](https://github.com/) account that you will use for this course.
#     * If you already have an account you can use it.
#     * All the repositories for the course will be created under our *Classroom*, not under your account.
# * **(Optional)** We will be using jupyter notebooks throughout the course. If you do not have the ability to run them, download Anaconda. Download and install [Anaconda](https://anaconda.org/) for [Python 3](https://www.anaconda.com/products/individual).
#     * [Installing on Windows — Anaconda documentation](https://docs.anaconda.com/anaconda/install/windows/)
#     * [Installing on macOS — Anaconda documentation](https://docs.anaconda.com/anaconda/install/mac-os/)
#     * [Installing on Linux — Anaconda documentation](https://docs.anaconda.com/anaconda/install/linux/)
# * **(Optional)** Download and install [GitHub Desktop](https://desktop.github.com/).
# * **(Optional)** Download and install the [Visual Studio Code](https://code.visualstudio.com/) text editor.
#     * You can download this [using Anaconda](https://docs.anaconda.com/anaconda/user-guide/tasks/integration/vscode/) or directly from [Microsoft](https://code.visualstudio.com/download).
#
# > The instructors will be using VS Code throughout the course. You can use a different editor, but you will receive limited support.
#
# # 5. Python Refresher
# ---
# The following are some texts on scientific programming with Python. We will use some of these throughout the course, but will not use one exclusively. Feel free to browse through them as a refresher on Python and as a preview to some of the topics we will be exploring in class.
#
# * [Official Python Documentation](https://www.python.org/doc/)
# * [Scientific Computing with Python by R. Johanson](http://raw.github.com/jrjohansson/scientific-python-lectures/master/Scientific-Computing-with-Python.pdf)
# * [Introduction to Scientific Computing](https://library.oapen.org/bitstream/id/56d27e73-e92a-4398-8198-239be7aacc93/2020_Book_IntroductionToScientificProgra.pdf)
# * [Python for Scientific Computing — Documentation](https://aaltoscicomp.github.io/python-for-scicomp/)
#
# # 6. UNIX Refresher
# ---
# Utilizing the command line is an essential skill in scientific computing. The following are resources to learn and review UNIX. After this week, the expectation will be that you can work comfortably from the command line and be able to construct and execute bash scripts.
#
# * [Tutorial - Linux Basics — UChicago CS Student Resource Guide](https://uchicago-cs.github.io/student-resource-guide/tutorials/linux-basics.html)
# * [Tutorial - Advanced Linux — UChicago CS Student Resource Guide](https://uchicago-cs.github.io/student-resource-guide/tutorials/linux-advanced.html)
# * [Command Line Crash Course](https://learnpythonthehardway.org/python3/appendixa.html): 15 exercises for common command line techniques.
#     > If you are using macOS, then follow the commands for Linux.
#
# # 7. Jupyter Notebook/Google Colaboratory Refresher
# ---
# The majority of assignments will utilize Jupyter Notebooks and require some familiarity with LaTeX for formatting mathematical equations and notations. Please review the following tutorials and articles.
#
# ### Jupyter Notebooks
# * Module 1: Jupyter Notebook Tutorial
# * [Jupyter Notebook: An Introduction – Real Python](https://realpython.com/jupyter-notebook-introduction/)
#
# ### Markdown
# * [Markdown Tutorial](https://www.markdowntutorial.com/)
# * [Markdown Guide](https://www.markdownguide.org/)
#
# ### LaTeX
# * Review the Module 1: LaTeX Notebook Tutorial
# * [Writing Math Equations in Jupyter Notebook: A Naive Introduction](https://medium.com/analytics-vidhya/writing-math-equations-in-jupyter-notebook-a-naive-introduction-a5ce87b9a214)
#
# # 8. Familiarize Yourself with a Text-based Editor
# ---
# We will be utilizing remote computing resources that will constrain us to working with classic (i.e., text-based) editors. While there is no general consensus on which is the best, there are three options that are universal and available across all platforms. Please familiarize yourself with one of them. You really just need to be comfortable with opening, editing, and saving files.
#
# ### Editor Wars!
# * [Nano vs. Emacs vs. Vim (Editor Wars!) | Linux Training Academy](https://www.linuxtrainingacademy.com/nano-emacs-vim/)
# * [Vim vs. Nano vs. Emacs: Three sysadmins weigh in | Enable Sysadmin](https://www.redhat.com/sysadmin/3-text-editors-compared)
#
# ### Nano
# * [Getting started with Nano | Enable Sysadmin](https://www.redhat.com/sysadmin/getting-started-nano)
#
# ### Vim
# * [Vim: Basic and intermediate commands | Enable Sysadmin](https://www.redhat.com/sysadmin/vim-commands)
# * [Interactive Vim Exercises](https://vim.is/#exercise)
# * [Interactive Vim tutorial](https://www.openvim.com/)
# * [Learn VIM while playing a game - VIM Adventures](https://vim-adventures.com/)
# * [How to Learn Vi - The Programmer's Favorite Editor](https://www.labnol.org/internet/learning-vim-for-beginners/28820/)
#
# ### Emacs
# * [A beginner’s guide to text editing with Emacs | Enable Sysadmin](https://www.redhat.com/sysadmin/beginners-guide-emacs)
#
# > **Submit the name of your new favorite text editor in the Canvas Text Field.**

# %% [markdown]
# ALL DONE!
